# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Neural Processes / Gaussian Neural Processes
#
# Esses modelos:
# 	•	aprendem distribuições sobre funções
# 	•	imitam o comportamento de GPs
# 	•	escalam melhor
#
# Mas:
# 	•	perdem garantias analíticas
# 	•	perdem positividade explícita da covariância
#
# São aproximadores de GPs, não substitutos conceituais.
