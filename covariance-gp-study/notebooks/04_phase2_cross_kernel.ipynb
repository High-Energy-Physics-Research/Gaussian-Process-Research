# %% [markdown]
# # Phase 2B: Cross-Kernel and Model Misspecification
#
# This notebook runs the full 3 x 3 truth/fit matrix and keeps sample covariance as an external baseline for every truth.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))

import pandas as pd
from src.experiments import load_config, run_phase2_cross_kernel

# %%
config = load_config(ROOT / 'configs/phase2.yaml')
df = run_phase2_cross_kernel(config, ROOT, overwrite=True)
df.head()

# %%
summary = pd.read_csv(ROOT / 'results/phase2/tables/cross_kernel_summary.csv')
summary.head(30)

# %% [markdown]
# When the model family is misspecified, increasing $M$ need not remove the Frobenius error. It can converge to an error floor corresponding to the closest covariance inside the fitted family.
