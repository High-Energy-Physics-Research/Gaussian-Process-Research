# %% [markdown]
# # Phase 1: Statistical Efficiency
#
# Question: how many realizations $M$ are required to recover a structured covariance matrix with a given precision? This notebook compares sample covariance, Diagonal, CS, and RBF covariance models for an RBF truth.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))

import pandas as pd
from src.experiments import load_config, run_phase1

# %%
config = load_config(ROOT / 'configs/phase1.yaml')
config

# %%
df = run_phase1(config, ROOT, overwrite=True)
df.head()

# %%
summary = pd.read_csv(ROOT / 'results/phase1/tables/frobenius_vs_M_summary.csv')
gain = pd.read_csv(ROOT / 'results/phase1/tables/statistical_gain_vs_M.csv')
display(summary)
display(gain)

# %% [markdown]
# The relevant scientific check is whether there is a range of $M$ where the median structured-estimator error is below the sample-covariance error. This is reported as statistical efficiency gain only when the ratio is larger than one.
