# %% [markdown]
# # Phase 2A: Correct Model and Parameter Recovery
#
# This notebook tests Diagonal -> Diagonal, CS -> CS, and RBF -> RBF across multiple true parameters and Monte Carlo repetitions.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))

import pandas as pd
from src.experiments import load_config, run_phase2_recovery

# %%
config = load_config(ROOT / 'configs/phase2.yaml')
df = run_phase2_recovery(config, ROOT, overwrite=True)
df.head()

# %%
df.groupby(['true_family', 'M'])['frobenius_error'].median().reset_index().head(20)
